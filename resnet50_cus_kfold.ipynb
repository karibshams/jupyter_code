# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

print('Modules loaded')
# Out:
# Modules loaded

# %%
data_dir =  r"D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB_Chest_Radiography_Database\image7500f"
filepaths = []
labels = []

for root, dirs, files in os.walk(data_dir):
    for file in files:
        file_path = os.path.join(root, file)
        filepaths.append(file_path)
        label = os.path.basename(root)
        labels.append(label)

df = pd.DataFrame({'filepaths': filepaths, 'labels': labels})
print(df)
# Out:
#                                               filepaths        labels
# 0     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 1     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 2     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 3     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 4     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# ...                                                 ...           ...
# 6995  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6996  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6997  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6998  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6999  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
#
# [7000 rows x 2 columns]

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
epochs = 10
k = 5 
NUM_CLASSES = 2

# %%
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()
val_gen = ImageDataGenerator()

# %%
kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
fold_var = 1

train_scores = []
valid_scores = []
test_scores = []
y_preds = []

# %%
for train_index, val_index in kf.split(df['filepaths'], df['labels']):
    print(f'Fold {fold_var}')
    
    train_df = df.iloc[train_index]
    valid_df = df.iloc[val_index]
    test_df = df.iloc[val_index]  

    train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    valid_gen = val_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    test_gen = ts_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
    img_size = (224, 224)
    channels = 3
    img_shape = (img_size[0], img_size[1], channels)
    class_count = len(train_gen.class_indices)
    

    base_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')

    base_model.trainable = False  

    model = Sequential([
    base_model,
    BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001),
    Dense(512, kernel_initializer='he_normal', activation='relu'),
    Dropout(0.2),
    Dense(256, kernel_regularizer=regularizers.l2(0.009), activity_regularizer=regularizers.l1(0.019),
          bias_regularizer=regularizers.l1(0.019), activation='relu'),
    Dropout(0.20),
    Dense(128, kernel_initializer='he_uniform', activation='relu'),
    Dropout(0.1),
    Dense(class_count, activation='softmax')
])

    model.compile(optimizer=Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    #model.summary()

    
    history = model.fit(x=train_gen, epochs=epochs, verbose=1, validation_data=valid_gen, validation_steps=None, shuffle=False)
    
   
    ts_length = len(test_df)
    test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length % n == 0 and ts_length / n <= 80]))
    test_steps = ts_length // test_batch_size
    
    train_score = model.evaluate(train_gen, steps=test_steps, verbose=1)
    valid_score = model.evaluate(valid_gen, steps=test_steps, verbose=1)
    test_score = model.evaluate(test_gen, steps=test_steps, verbose=1)
    
    train_scores.append(train_score)
    valid_scores.append(valid_score)
    test_scores.append(test_score)
    
    preds = model.predict(test_gen)
    y_pred = np.argmax(preds, axis=1)
    y_preds.append(y_pred)
    
    fold_var += 1
# Out:
# Fold 1
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 759s 4s/step - loss: 1.7505 - accuracy: 0.9498 - val_loss: 0.6399 - val_accuracy: 0.9507
# Epoch 2/10
# 175/175 [==============================] - 668s 4s/step - loss: 0.3993 - accuracy: 0.9580 - val_loss: 0.2689 - val_accuracy: 0.9836
# Epoch 3/10
# 175/175 [==============================] - 637s 4s/step - loss: 0.2876 - accuracy: 0.9602 - val_loss: 0.2214 - val_accuracy: 0.9814
# Epoch 4/10
# 175/175 [==============================] - 614s 4s/step - loss: 0.2710 - accuracy: 0.9650 - val_loss: 0.2078 - val_accuracy: 0.9836
# Epoch 5/10
# 175/175 [==============================] - 606s 3s/step - loss: 0.2431 - accuracy: 0.9675 - val_loss: 0.1870 - val_accuracy: 0.9721
# Epoch 6/10
# 175/175 [==============================] - 604s 3s/step - loss: 0.2390 - accuracy: 0.9754 - val_loss: 0.2243 - val_accuracy: 0.9821
# Epoch 7/10
# 175/175 [==============================] - 610s 3s/step - loss: 0.2568 - accuracy: 0.9696 - val_loss: 0.2329 - val_accuracy: 0.9786
# Epoch 8/10
# 175/175 [==============================] - 602s 3s/step - loss: 0.2191 - accuracy: 0.9780 - val_loss: 0.1726 - val_accuracy: 0.9871
# Epoch 9/10
# 175/175 [==============================] - 603s 3s/step - loss: 0.2012 - accuracy: 0.9798 - val_loss: 0.1923 - val_accuracy: 0.9814
# Epoch 10/10
# 175/175 [==============================] - 859s 5s/step - loss: 0.2319 - accuracy: 0.9768 - val_loss: 0.2592 - val_accuracy: 0.9771
# 20/20 [==============================] - 94s 5s/step - loss: 0.2034 - accuracy: 0.9937
# 20/20 [==============================] - 95s 5s/step - loss: 0.2602 - accuracy: 0.9781
# 20/20 [==============================] - 103s 5s/step - loss: 0.1926 - accuracy: 0.9750
# 44/44 [==============================] - 214s 5s/step
# Fold 2
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 1044s 6s/step - loss: 1.8560 - accuracy: 0.9418 - val_loss: 0.6312 - val_accuracy: 0.9671
# Epoch 2/10
# 175/175 [==============================] - 1057s 6s/step - loss: 0.4104 - accuracy: 0.9643 - val_loss: 0.2754 - val_accuracy: 0.9807
# Epoch 3/10
# 175/175 [==============================] - 1045s 6s/step - loss: 0.2767 - accuracy: 0.9575 - val_loss: 0.2512 - val_accuracy: 0.9771
# Epoch 4/10
# 175/175 [==============================] - 1060s 6s/step - loss: 0.2537 - accuracy: 0.9646 - val_loss: 0.1998 - val_accuracy: 0.9771
# Epoch 5/10
# 175/175 [==============================] - 1026s 6s/step - loss: 0.2630 - accuracy: 0.9586 - val_loss: 0.2407 - val_accuracy: 0.9871
# Epoch 6/10
# 175/175 [==============================] - 1031s 6s/step - loss: 0.2387 - accuracy: 0.9702 - val_loss: 0.1832 - val_accuracy: 0.9800
# Epoch 7/10
# 175/175 [==============================] - 642s 4s/step - loss: 0.2465 - accuracy: 0.9621 - val_loss: 0.1942 - val_accuracy: 0.9807
# Epoch 8/10
# 175/175 [==============================] - 600s 3s/step - loss: 0.2432 - accuracy: 0.9641 - val_loss: 0.1741 - val_accuracy: 0.9843
# Epoch 9/10
# 175/175 [==============================] - 600s 3s/step - loss: 0.2188 - accuracy: 0.9734 - val_loss: 0.2026 - val_accuracy: 0.9857
# Epoch 10/10
# 175/175 [==============================] - 605s 3s/step - loss: 0.2227 - accuracy: 0.9780 - val_loss: 0.1989 - val_accuracy: 0.9779
# 20/20 [==============================] - 61s 3s/step - loss: 0.1694 - accuracy: 0.9875
# 20/20 [==============================] - 56s 3s/step - loss: 0.1986 - accuracy: 0.9719
# 20/20 [==============================] - 56s 3s/step - loss: 0.1182 - accuracy: 0.9937
# 44/44 [==============================] - 120s 3s/step
# Fold 3
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 641s 4s/step - loss: 1.7997 - accuracy: 0.9429 - val_loss: 0.6070 - val_accuracy: 0.9350
# Epoch 2/10
# 175/175 [==============================] - 619s 4s/step - loss: 0.3698 - accuracy: 0.9673 - val_loss: 0.2473 - val_accuracy: 0.9679
# Epoch 3/10
# 175/175 [==============================] - 616s 4s/step - loss: 0.2713 - accuracy: 0.9559 - val_loss: 0.1893 - val_accuracy: 0.9821
# Epoch 4/10
# 175/175 [==============================] - 614s 4s/step - loss: 0.2521 - accuracy: 0.9595 - val_loss: 0.2020 - val_accuracy: 0.9807
# Epoch 5/10
# 175/175 [==============================] - 607s 3s/step - loss: 0.2451 - accuracy: 0.9627 - val_loss: 0.2375 - val_accuracy: 0.9857
# Epoch 6/10
# 175/175 [==============================] - 612s 4s/step - loss: 0.2540 - accuracy: 0.9611 - val_loss: 0.2160 - val_accuracy: 0.9886
# Epoch 7/10
# 175/175 [==============================] - 607s 3s/step - loss: 0.2264 - accuracy: 0.9711 - val_loss: 0.1845 - val_accuracy: 0.9886
# Epoch 8/10
# 175/175 [==============================] - 604s 3s/step - loss: 0.2325 - accuracy: 0.9698 - val_loss: 0.1982 - val_accuracy: 0.9857
# Epoch 9/10
# 175/175 [==============================] - 608s 3s/step - loss: 0.2209 - accuracy: 0.9762 - val_loss: 0.1799 - val_accuracy: 0.9843
# Epoch 10/10
# 175/175 [==============================] - 605s 3s/step - loss: 0.2302 - accuracy: 0.9725 - val_loss: 0.2028 - val_accuracy: 0.9814
# 20/20 [==============================] - 55s 3s/step - loss: 0.1831 - accuracy: 0.9891
# 20/20 [==============================] - 56s 3s/step - loss: 0.2067 - accuracy: 0.9812
# 20/20 [==============================] - 56s 3s/step - loss: 0.1113 - accuracy: 0.9891
# 44/44 [==============================] - 166s 4s/step
# Fold 4
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 1059s 6s/step - loss: 1.8413 - accuracy: 0.9446 - val_loss: 0.6618 - val_accuracy: 0.9400
# Epoch 2/10
# 175/175 [==============================] - 1042s 6s/step - loss: 0.4227 - accuracy: 0.9557 - val_loss: 0.2735 - val_accuracy: 0.9693
# Epoch 3/10
# 175/175 [==============================] - 1047s 6s/step - loss: 0.2885 - accuracy: 0.9588 - val_loss: 0.2116 - val_accuracy: 0.9836
# Epoch 4/10
# 175/175 [==============================] - 1048s 6s/step - loss: 0.2652 - accuracy: 0.9573 - val_loss: 0.1942 - val_accuracy: 0.9800
# Epoch 5/10
# 175/175 [==============================] - 1051s 6s/step - loss: 0.2175 - accuracy: 0.9682 - val_loss: 0.1783 - val_accuracy: 0.9807
# Epoch 6/10
# 175/175 [==============================] - 859s 5s/step - loss: 0.2145 - accuracy: 0.9707 - val_loss: 0.1512 - val_accuracy: 0.9907
# Epoch 7/10
# 175/175 [==============================] - 584s 3s/step - loss: 0.1939 - accuracy: 0.9786 - val_loss: 0.1828 - val_accuracy: 0.9843
# Epoch 8/10
# 175/175 [==============================] - 620s 4s/step - loss: 0.2106 - accuracy: 0.9771 - val_loss: 0.2068 - val_accuracy: 0.9879
# Epoch 9/10
# 175/175 [==============================] - 621s 4s/step - loss: 0.2041 - accuracy: 0.9789 - val_loss: 0.1863 - val_accuracy: 0.9879
# Epoch 10/10
# 175/175 [==============================] - 613s 4s/step - loss: 0.1858 - accuracy: 0.9818 - val_loss: 0.1471 - val_accuracy: 0.9914
# 20/20 [==============================] - 56s 3s/step - loss: 0.1288 - accuracy: 0.9984
# 20/20 [==============================] - 56s 3s/step - loss: 0.1356 - accuracy: 0.9922
# 20/20 [==============================] - 57s 3s/step - loss: 0.2295 - accuracy: 0.9844
# 44/44 [==============================] - 128s 3s/step
# Fold 5
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 632s 4s/step - loss: 1.7999 - accuracy: 0.9464 - val_loss: 0.6136 - val_accuracy: 0.9614
# Epoch 2/10
# 175/175 [==============================] - 623s 4s/step - loss: 0.4204 - accuracy: 0.9538 - val_loss: 0.2896 - val_accuracy: 0.9764
# Epoch 3/10
# 175/175 [==============================] - 615s 4s/step - loss: 0.2838 - accuracy: 0.9632 - val_loss: 0.2453 - val_accuracy: 0.9771
# Epoch 4/10
# 175/175 [==============================] - 610s 3s/step - loss: 0.2553 - accuracy: 0.9670 - val_loss: 0.2350 - val_accuracy: 0.9707
# Epoch 5/10
# 175/175 [==============================] - 617s 4s/step - loss: 0.2479 - accuracy: 0.9691 - val_loss: 0.1945 - val_accuracy: 0.9786
# Epoch 6/10
# 175/175 [==============================] - 618s 4s/step - loss: 0.2510 - accuracy: 0.9698 - val_loss: 0.2719 - val_accuracy: 0.9671
# Epoch 7/10
# 175/175 [==============================] - 618s 4s/step - loss: 0.2359 - accuracy: 0.9761 - val_loss: 0.1931 - val_accuracy: 0.9857
# Epoch 8/10
# 175/175 [==============================] - 632s 4s/step - loss: 0.2128 - accuracy: 0.9802 - val_loss: 0.2026 - val_accuracy: 0.9857
# Epoch 9/10
# 175/175 [==============================] - 628s 4s/step - loss: 0.1978 - accuracy: 0.9820 - val_loss: 0.2046 - val_accuracy: 0.9764
# Epoch 10/10
# 175/175 [==============================] - 712s 4s/step - loss: 0.1980 - accuracy: 0.9798 - val_loss: 0.2769 - val_accuracy: 0.9614
# 20/20 [==============================] - 97s 5s/step - loss: 0.2459 - accuracy: 0.9750
# 20/20 [==============================] - 97s 5s/step - loss: 0.2448 - accuracy: 0.9625
# 20/20 [==============================] - 98s 5s/step - loss: 0.3406 - accuracy: 0.9375
# 44/44 [==============================] - 212s 5s/step

# %%
train_loss = np.mean([score[0] for score in train_scores])
train_acc = np.mean([score[1] for score in train_scores])
valid_loss = np.mean([score[0] for score in valid_scores])
valid_acc = np.mean([score[1] for score in valid_scores])
test_loss = np.mean([score[0] for score in test_scores])
test_acc = np.mean([score[1] for score in test_scores])

print("Train Loss: ", train_loss)
print("Train Accuracy: ", train_acc)
print('-' * 20)
print("Validation Loss: ", valid_loss)
print("Validation Accuracy: ", valid_acc)
print('-' * 20)
print("Test Loss: ", test_loss)
print("Test Accuracy: ", test_acc)
# Out:
# Train Loss:  0.18610798716545104
# Train Accuracy:  0.9887500047683716
# --------------------
# Validation Loss:  0.20918143391609192
# Validation Accuracy:  0.9771874904632568
# --------------------
# Test Loss:  0.1984458014369011
# Test Accuracy:  0.9759374976158142

# %%
y_true = test_gen.classes
classes = list(train_gen.class_indices.keys())
print(classification_report(y_true, y_preds[-1], target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.94      0.96       700
# Tuberculosis       0.94      0.99      0.96       700
#
#     accuracy                           0.96      1400
#    macro avg       0.96      0.96      0.96      1400
# weighted avg       0.96      0.96      0.96      1400

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


cm = confusion_matrix(y_true, y_preds[-1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)

# Plot confusion matrix
plt.figure(figsize=(10, 10))
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import tensorflow as tf
import pickle

# Save the model in HDF5 format
model.save(r"D:\CAPSTONE 400A\model\resnet50kfoldcus.h5")

# %%
model.save("resnet50kfoldcus.h5")
