# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

print('Modules loaded')
# Out:
# Modules loaded

# %%
data_dir =  r"D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB_Chest_Radiography_Database\image7500f"
filepaths = []
labels = []

for root, dirs, files in os.walk(data_dir):
    for file in files:
        file_path = os.path.join(root, file)
        filepaths.append(file_path)
        label = os.path.basename(root)
        labels.append(label)

df = pd.DataFrame({'filepaths': filepaths, 'labels': labels})
print(df)
# Out:
#                                               filepaths        labels
# 0     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 1     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 2     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 3     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 4     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# ...                                                 ...           ...
# 6995  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6996  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6997  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6998  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6999  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
#
# [7000 rows x 2 columns]

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
epochs = 10
k = 5 
NUM_CLASSES = 2

# %%
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()
val_gen = ImageDataGenerator()

# %%
kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
fold_var = 1

train_scores = []
valid_scores = []
test_scores = []
y_preds = []

# %%
for train_index, val_index in kf.split(df['filepaths'], df['labels']):
    print(f'Fold {fold_var}')
    
    train_df = df.iloc[train_index]
    valid_df = df.iloc[val_index]
    test_df = df.iloc[val_index]  

    train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    valid_gen = val_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    test_gen = ts_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
    img_size = (224, 224)
    channels = 3
    img_shape = (img_size[0], img_size[1], channels)
    class_count = len(train_gen.class_indices)
    

    base_model = tf.keras.applications.DenseNet121(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')

    base_model.trainable = False  

    model = Sequential([
    base_model,
    BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001),
    Dense(512, kernel_initializer='he_normal', activation='relu'),
    Dropout(0.2),
    Dense(256, kernel_regularizer=regularizers.l2(0.009), activity_regularizer=regularizers.l1(0.019),
          bias_regularizer=regularizers.l1(0.019), activation='relu'),
    Dropout(0.20),
    Dense(128, kernel_initializer='he_uniform', activation='relu'),
    Dropout(0.1),
    Dense(class_count, activation='softmax')
])

    model.compile(optimizer=Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    #model.summary()

    
    history = model.fit(x=train_gen, epochs=epochs, verbose=1, validation_data=valid_gen, validation_steps=None, shuffle=False)
    
   
    ts_length = len(test_df)
    test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length % n == 0 and ts_length / n <= 80]))
    test_steps = ts_length // test_batch_size
    
    train_score = model.evaluate(train_gen, steps=test_steps, verbose=1)
    valid_score = model.evaluate(valid_gen, steps=test_steps, verbose=1)
    test_score = model.evaluate(test_gen, steps=test_steps, verbose=1)
    
    train_scores.append(train_score)
    valid_scores.append(valid_score)
    test_scores.append(test_score)
    
    preds = model.predict(test_gen)
    y_pred = np.argmax(preds, axis=1)
    y_preds.append(y_pred)
    
    fold_var += 1
# Out:
# Fold 1
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 583s 3s/step - loss: 1.8487 - accuracy: 0.9413 - val_loss: 0.6007 - val_accuracy: 0.9621
# Epoch 2/10
# 175/175 [==============================] - 599s 3s/step - loss: 0.4006 - accuracy: 0.9559 - val_loss: 0.2300 - val_accuracy: 0.9714
# Epoch 3/10
# 175/175 [==============================] - 589s 3s/step - loss: 0.2371 - accuracy: 0.9664 - val_loss: 0.1874 - val_accuracy: 0.9779
# Epoch 4/10
# 175/175 [==============================] - 587s 3s/step - loss: 0.2133 - accuracy: 0.9646 - val_loss: 0.1661 - val_accuracy: 0.9871
# Epoch 5/10
# 175/175 [==============================] - 587s 3s/step - loss: 0.1682 - accuracy: 0.9721 - val_loss: 0.1368 - val_accuracy: 0.9836
# Epoch 6/10
# 175/175 [==============================] - 597s 3s/step - loss: 0.1415 - accuracy: 0.9823 - val_loss: 0.1614 - val_accuracy: 0.9829
# Epoch 7/10
# 175/175 [==============================] - 591s 3s/step - loss: 0.1273 - accuracy: 0.9857 - val_loss: 0.1071 - val_accuracy: 0.9829
# Epoch 8/10
# 175/175 [==============================] - 593s 3s/step - loss: 0.1257 - accuracy: 0.9834 - val_loss: 0.1136 - val_accuracy: 0.9843
# Epoch 9/10
# 175/175 [==============================] - 640s 4s/step - loss: 0.1124 - accuracy: 0.9854 - val_loss: 0.1011 - val_accuracy: 0.9864
# Epoch 10/10
# 175/175 [==============================] - 1018s 6s/step - loss: 0.0867 - accuracy: 0.9916 - val_loss: 0.0881 - val_accuracy: 0.9857
# 20/20 [==============================] - 93s 5s/step - loss: 0.0559 - accuracy: 1.0000
# 20/20 [==============================] - 93s 5s/step - loss: 0.1008 - accuracy: 0.9844
# 20/20 [==============================] - 95s 5s/step - loss: 0.0949 - accuracy: 0.9844
# 44/44 [==============================] - 207s 5s/step
# Fold 2
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 1041s 6s/step - loss: 1.6717 - accuracy: 0.9339 - val_loss: 0.4823 - val_accuracy: 0.9636
# Epoch 2/10
# 175/175 [==============================] - 1027s 6s/step - loss: 0.3276 - accuracy: 0.9620 - val_loss: 0.2041 - val_accuracy: 0.9829
# Epoch 3/10
# 175/175 [==============================] - 1027s 6s/step - loss: 0.2281 - accuracy: 0.9620 - val_loss: 0.1571 - val_accuracy: 0.9836
# Epoch 4/10
# 175/175 [==============================] - 1051s 6s/step - loss: 0.1966 - accuracy: 0.9696 - val_loss: 0.1308 - val_accuracy: 0.9879
# Epoch 5/10
# 175/175 [==============================] - 1033s 6s/step - loss: 0.1564 - accuracy: 0.9755 - val_loss: 0.1238 - val_accuracy: 0.9843
# Epoch 6/10
# 175/175 [==============================] - 1026s 6s/step - loss: 0.1426 - accuracy: 0.9779 - val_loss: 0.1329 - val_accuracy: 0.9829
# Epoch 7/10
# 175/175 [==============================] - 700s 4s/step - loss: 0.1242 - accuracy: 0.9816 - val_loss: 0.1041 - val_accuracy: 0.9886
# Epoch 8/10
# 175/175 [==============================] - 585s 3s/step - loss: 0.1035 - accuracy: 0.9870 - val_loss: 0.0882 - val_accuracy: 0.9929
# Epoch 9/10
# 175/175 [==============================] - 594s 3s/step - loss: 0.1060 - accuracy: 0.9843 - val_loss: 0.0974 - val_accuracy: 0.9900
# Epoch 10/10
# 175/175 [==============================] - 596s 3s/step - loss: 0.0943 - accuracy: 0.9862 - val_loss: 0.0906 - val_accuracy: 0.9907
# 20/20 [==============================] - 54s 3s/step - loss: 0.0602 - accuracy: 1.0000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0896 - accuracy: 0.9922
# 20/20 [==============================] - 55s 3s/step - loss: 0.0906 - accuracy: 0.9937
# 44/44 [==============================] - 120s 3s/step
# Fold 3
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 623s 4s/step - loss: 1.5947 - accuracy: 0.9461 - val_loss: 0.4293 - val_accuracy: 0.9664
# Epoch 2/10
# 175/175 [==============================] - 611s 3s/step - loss: 0.3373 - accuracy: 0.9602 - val_loss: 0.2144 - val_accuracy: 0.9729
# Epoch 3/10
# 175/175 [==============================] - 616s 4s/step - loss: 0.2270 - accuracy: 0.9675 - val_loss: 0.1609 - val_accuracy: 0.9850
# Epoch 4/10
# 175/175 [==============================] - 610s 3s/step - loss: 0.1971 - accuracy: 0.9743 - val_loss: 0.1541 - val_accuracy: 0.9843
# Epoch 5/10
# 175/175 [==============================] - 613s 4s/step - loss: 0.1751 - accuracy: 0.9764 - val_loss: 0.1407 - val_accuracy: 0.9800
# Epoch 6/10
# 175/175 [==============================] - 606s 3s/step - loss: 0.1457 - accuracy: 0.9827 - val_loss: 0.1285 - val_accuracy: 0.9829
# Epoch 7/10
# 175/175 [==============================] - 609s 3s/step - loss: 0.1381 - accuracy: 0.9839 - val_loss: 0.1228 - val_accuracy: 0.9864
# Epoch 8/10
# 175/175 [==============================] - 608s 3s/step - loss: 0.1319 - accuracy: 0.9843 - val_loss: 0.0980 - val_accuracy: 0.9900
# Epoch 9/10
# 175/175 [==============================] - 621s 4s/step - loss: 0.0984 - accuracy: 0.9916 - val_loss: 0.0934 - val_accuracy: 0.9864
# Epoch 10/10
# 175/175 [==============================] - 611s 3s/step - loss: 0.1101 - accuracy: 0.9861 - val_loss: 0.1051 - val_accuracy: 0.9886
# 20/20 [==============================] - 57s 3s/step - loss: 0.0706 - accuracy: 1.0000
# 20/20 [==============================] - 56s 3s/step - loss: 0.1246 - accuracy: 0.9828
# 20/20 [==============================] - 56s 3s/step - loss: 0.1305 - accuracy: 0.9875
# 44/44 [==============================] - 123s 3s/step
# Fold 4
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 621s 4s/step - loss: 1.6918 - accuracy: 0.9327 - val_loss: 0.5076 - val_accuracy: 0.9650
# Epoch 2/10
# 175/175 [==============================] - 614s 4s/step - loss: 0.3540 - accuracy: 0.9638 - val_loss: 0.2127 - val_accuracy: 0.9871
# Epoch 3/10
# 175/175 [==============================] - 615s 4s/step - loss: 0.2490 - accuracy: 0.9666 - val_loss: 0.1751 - val_accuracy: 0.9864
# Epoch 4/10
# 175/175 [==============================] - 614s 4s/step - loss: 0.2070 - accuracy: 0.9729 - val_loss: 0.1536 - val_accuracy: 0.9871
# Epoch 5/10
# 175/175 [==============================] - 614s 4s/step - loss: 0.1771 - accuracy: 0.9725 - val_loss: 0.1540 - val_accuracy: 0.9893
# Epoch 6/10
# 175/175 [==============================] - 618s 4s/step - loss: 0.1572 - accuracy: 0.9793 - val_loss: 0.1377 - val_accuracy: 0.9907
# Epoch 7/10
# 175/175 [==============================] - 612s 3s/step - loss: 0.1295 - accuracy: 0.9843 - val_loss: 0.1206 - val_accuracy: 0.9857
# Epoch 8/10
# 175/175 [==============================] - 616s 4s/step - loss: 0.1274 - accuracy: 0.9843 - val_loss: 0.1069 - val_accuracy: 0.9850
# Epoch 9/10
# 175/175 [==============================] - 612s 3s/step - loss: 0.1126 - accuracy: 0.9879 - val_loss: 0.1165 - val_accuracy: 0.9900
# Epoch 10/10
# 175/175 [==============================] - 614s 4s/step - loss: 0.0933 - accuracy: 0.9911 - val_loss: 0.1085 - val_accuracy: 0.9907
# 20/20 [==============================] - 56s 3s/step - loss: 0.0670 - accuracy: 0.9984
# 20/20 [==============================] - 56s 3s/step - loss: 0.0894 - accuracy: 0.9922
# 20/20 [==============================] - 56s 3s/step - loss: 0.1097 - accuracy: 0.9875
# 44/44 [==============================] - 123s 3s/step
# Fold 5
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 626s 4s/step - loss: 1.6978 - accuracy: 0.9438 - val_loss: 0.4951 - val_accuracy: 0.9686
# Epoch 2/10
# 175/175 [==============================] - 618s 4s/step - loss: 0.3413 - accuracy: 0.9648 - val_loss: 0.2211 - val_accuracy: 0.9814
# Epoch 3/10
# 175/175 [==============================] - 617s 4s/step - loss: 0.2277 - accuracy: 0.9689 - val_loss: 0.1805 - val_accuracy: 0.9764
# Epoch 4/10
# 175/175 [==============================] - 614s 4s/step - loss: 0.2018 - accuracy: 0.9714 - val_loss: 0.2095 - val_accuracy: 0.9793
# Epoch 5/10
# 175/175 [==============================] - 614s 4s/step - loss: 0.1849 - accuracy: 0.9741 - val_loss: 0.1480 - val_accuracy: 0.9771
# Epoch 6/10
# 175/175 [==============================] - 621s 4s/step - loss: 0.1529 - accuracy: 0.9777 - val_loss: 0.1656 - val_accuracy: 0.9857
# Epoch 7/10
# 175/175 [==============================] - 615s 4s/step - loss: 0.1434 - accuracy: 0.9834 - val_loss: 0.1345 - val_accuracy: 0.9814
# Epoch 8/10
# 175/175 [==============================] - 616s 4s/step - loss: 0.1150 - accuracy: 0.9870 - val_loss: 0.1256 - val_accuracy: 0.9850
# Epoch 9/10
# 175/175 [==============================] - 616s 4s/step - loss: 0.1094 - accuracy: 0.9871 - val_loss: 0.1351 - val_accuracy: 0.9836
# Epoch 10/10
# 175/175 [==============================] - 616s 4s/step - loss: 0.1043 - accuracy: 0.9868 - val_loss: 0.1158 - val_accuracy: 0.9864
# 20/20 [==============================] - 57s 3s/step - loss: 0.0725 - accuracy: 0.9984
# 20/20 [==============================] - 57s 3s/step - loss: 0.1137 - accuracy: 0.9891
# 20/20 [==============================] - 57s 3s/step - loss: 0.1148 - accuracy: 0.9859
# 44/44 [==============================] - 125s 3s/step

# %%
train_loss = np.mean([score[0] for score in train_scores])
train_acc = np.mean([score[1] for score in train_scores])
valid_loss = np.mean([score[0] for score in valid_scores])
valid_acc = np.mean([score[1] for score in valid_scores])
test_loss = np.mean([score[0] for score in test_scores])
test_acc = np.mean([score[1] for score in test_scores])

print("Train Loss: ", train_loss)
print("Train Accuracy: ", train_acc)
print('-' * 20)
print("Validation Loss: ", valid_loss)
print("Validation Accuracy: ", valid_acc)
print('-' * 20)
print("Test Loss: ", test_loss)
print("Test Accuracy: ", test_acc)
# Out:
# Train Loss:  0.06523201242089272
# Train Accuracy:  0.9993750095367432
# --------------------
# Validation Loss:  0.10362186878919602
# Validation Accuracy:  0.9881250023841858
# --------------------
# Test Loss:  0.10809898376464844
# Test Accuracy:  0.9878124952316284

# %%
y_true = test_gen.classes
classes = list(train_gen.class_indices.keys())
print(classification_report(y_true, y_preds[-1], target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.99      0.99       700
# Tuberculosis       0.99      0.99      0.99       700
#
#     accuracy                           0.99      1400
#    macro avg       0.99      0.99      0.99      1400
# weighted avg       0.99      0.99      0.99      1400

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


cm = confusion_matrix(y_true, y_preds[-1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)

# Plot confusion matrix
plt.figure(figsize=(10, 10))
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import tensorflow as tf
import pickle

# Save the model in HDF5 format
model.save(r"D:\CAPSTONE 400A\model\DenseNet121kfoldcus.h5")

# %%
model.save("DenseNet121kfoldcus.h5")
