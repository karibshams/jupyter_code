# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adamax
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

print('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r"D:\CapstoneB\MKN maam\image7500f"
filepaths = []
labels = []

for root, dirs, files in os.walk(data_dir):
    for file in files:
        file_path = os.path.join(root, file)
        filepaths.append(file_path)
        label = os.path.basename(root)
        labels.append(label)

df = pd.DataFrame({'filepaths': filepaths, 'labels': labels})
labels = df['labels']
print(df)
# Out:
#                                               filepaths        labels
# 0     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 1     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 2     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 3     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 4     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# ...                                                 ...           ...
# 6995  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6996  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6997  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6998  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6999  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
#
# [7000 rows x 2 columns]

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
epochs = 10
k = 5  
NUM_CLASSES = 2

# %%
def get_callbacks(model_name):
    callbacks = []
    checkpoint = ModelCheckpoint(filepath=f'model.{model_name}.keras', verbose=1, monitor='val_accuracy', mode='max')
    callbacks.append(checkpoint)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
    callbacks.append(reduce_lr)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
    callbacks.append(early_stopping)
    return callbacks

def build_model():
    base_model = tf.keras.applications.VGG19(input_shape=img_shape, include_top=False, weights='imagenet')
    base_model.trainable = True
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer=Adamax(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=123)
fold_no = 1
accuracies = []

# %%
# Create lists to store history data for each fold
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []

# Create a list to store confusion matrices
confusion_matrices = []

for train_index, test_index in skf.split(df['filepaths'], df['labels']):
    train_df = df.iloc[train_index]
    test_df = df.iloc[test_index]

    tr_gen = ImageDataGenerator()
    ts_gen = ImageDataGenerator()

    train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels',
                                           target_size=img_size, class_mode='categorical',
                                           color_mode='rgb', shuffle=True, batch_size=batch_size)

    test_gen = ts_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels',
                                          target_size=img_size, class_mode='categorical',
                                          color_mode='rgb', shuffle=False, batch_size=batch_size)

    g_dict = train_gen.class_indices
    classes = list(g_dict.keys())
    class_count = len(classes)

    model = build_model()
    callbacks = get_callbacks(f'VGG19_fold_{fold_no}')

    history = model.fit(train_gen,
                        epochs=epochs,
                        validation_data=test_gen,
                        callbacks=callbacks)

    # Store history data
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])

    ts_length = len(test_df)
    test_batch_size = min(32, ts_length)
    test_steps = ts_length // test_batch_size

    test_score = model.evaluate(test_gen, steps=test_steps, verbose=1)
    print(f"Fold {fold_no} - Test Loss: ", test_score[0])
    print(f"Fold {fold_no} - Test Accuracy: ", test_score[1])

    preds = model.predict(test_gen)
    y_pred = np.argmax(preds, axis=1)
    print(f"Classification Report for Fold {fold_no}")
    print(classification_report(test_gen.classes, y_pred, target_names=classes))

    # Store confusion matrix
    cm = confusion_matrix(test_gen.classes, y_pred)
    confusion_matrices.append(cm)

    accuracies.append(test_score[1])
    fold_no += 1
# Out:
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.4834 - loss: 419.4233
# Epoch 1: saving model to model.VGG19_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1598s 9s/step - accuracy: 0.4835 - loss: 417.5456 - val_accuracy: 0.4993 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4931 - loss: 0.6932
# Epoch 2: saving model to model.VGG19_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1573s 9s/step - accuracy: 0.4932 - loss: 0.6932 - val_accuracy: 0.4993 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4908 - loss: 0.6932
# Epoch 3: saving model to model.VGG19_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1574s 9s/step - accuracy: 0.4908 - loss: 0.6932 - val_accuracy: 0.4993 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5000 - loss: 0.6932
# Epoch 4: saving model to model.VGG19_fold_1.keras
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1580s 9s/step - accuracy: 0.4999 - loss: 0.6932 - val_accuracy: 0.4993 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.4953 - loss: 0.6932
# Epoch 5: saving model to model.VGG19_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1576s 9s/step - accuracy: 0.4953 - loss: 0.6932 - val_accuracy: 0.4993 - val_loss: 0.6932 - learning_rate: 2.0000e-04
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.5112 - loss: 0.6931
# Epoch 6: saving model to model.VGG19_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1574s 9s/step - accuracy: 0.5111 - loss: 0.6931 - val_accuracy: 0.4993 - val_loss: 0.6932 - learning_rate: 2.0000e-04
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4948 - loss: 0.6932
# Epoch 7: saving model to model.VGG19_fold_1.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1574s 9s/step - accuracy: 0.4948 - loss: 0.6932 - val_accuracy: 0.4993 - val_loss: 0.6932 - learning_rate: 2.0000e-04
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4969 - loss: 0.6932
# Epoch 8: saving model to model.VGG19_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1574s 9s/step - accuracy: 0.4969 - loss: 0.6932 - val_accuracy: 0.4993 - val_loss: 0.6932 - learning_rate: 4.0000e-05
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.8384 - loss: 0.6920
# Fold 1 - Test Loss:  0.6931211948394775
# Fold 1 - Test Accuracy:  0.5079941749572754
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step
# Classification Report for Fold 1
#               precision    recall  f1-score   support
#
#       Normal       0.50      1.00      0.67       700
# Tuberculosis       0.00      0.00      0.00       700
#
#     accuracy                           0.50      1400
#    macro avg       0.25      0.50      0.33      1400
# weighted avg       0.25      0.50      0.33      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5045 - loss: 961.5038
# Epoch 1: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1580s 9s/step - accuracy: 0.5044 - loss: 957.1953 - val_accuracy: 0.5014 - val_loss: 0.6892 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5407 - loss: 0.6805
# Epoch 2: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1591s 9s/step - accuracy: 0.5410 - loss: 0.6805 - val_accuracy: 0.6286 - val_loss: 0.6464 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.6735 - loss: 0.6423
# Epoch 3: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1641s 9s/step - accuracy: 0.6736 - loss: 0.6423 - val_accuracy: 0.7114 - val_loss: 0.5926 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.7170 - loss: 0.6084
# Epoch 4: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1654s 9s/step - accuracy: 0.7170 - loss: 0.6084 - val_accuracy: 0.7471 - val_loss: 0.5508 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.7254 - loss: 0.5383
# Epoch 5: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1655s 9s/step - accuracy: 0.7255 - loss: 0.5383 - val_accuracy: 0.7986 - val_loss: 0.4481 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.7962 - loss: 0.4410
# Epoch 6: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1685s 10s/step - accuracy: 0.7964 - loss: 0.4407 - val_accuracy: 0.9221 - val_loss: 0.2342 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9108 - loss: 0.2446
# Epoch 7: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1663s 10s/step - accuracy: 0.9109 - loss: 0.2445 - val_accuracy: 0.9293 - val_loss: 0.2171 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9347 - loss: 0.1862
# Epoch 8: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1583s 9s/step - accuracy: 0.9347 - loss: 0.1860 - val_accuracy: 0.9607 - val_loss: 0.1009 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9545 - loss: 0.1187
# Epoch 9: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1579s 9s/step - accuracy: 0.9546 - loss: 0.1187 - val_accuracy: 0.9743 - val_loss: 0.0663 - learning_rate: 0.0010
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9592 - loss: 0.1143
# Epoch 10: saving model to model.VGG19_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1583s 9s/step - accuracy: 0.9592 - loss: 0.1143 - val_accuracy: 0.9686 - val_loss: 0.0895 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 9.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9652 - loss: 0.0767
# Fold 2 - Test Loss:  0.06396413594484329
# Fold 2 - Test Accuracy:  0.9745639562606812
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step
# Classification Report for Fold 2
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.96      0.97       700
# Tuberculosis       0.96      0.99      0.97       700
#
#     accuracy                           0.97      1400
#    macro avg       0.97      0.97      0.97      1400
# weighted avg       0.97      0.97      0.97      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5247 - loss: 2122.4961
# Epoch 1: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1587s 9s/step - accuracy: 0.5248 - loss: 2112.9810 - val_accuracy: 0.5000 - val_loss: 0.6919 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5939 - loss: 0.6727
# Epoch 2: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1591s 9s/step - accuracy: 0.5942 - loss: 0.6726 - val_accuracy: 0.8236 - val_loss: 0.5480 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.8341 - loss: 0.5290
# Epoch 3: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1578s 9s/step - accuracy: 0.8341 - loss: 0.5289 - val_accuracy: 0.8786 - val_loss: 0.4578 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.8776 - loss: 0.4627
# Epoch 4: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1580s 9s/step - accuracy: 0.8776 - loss: 0.4626 - val_accuracy: 0.8879 - val_loss: 0.4233 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.8852 - loss: 0.4309
# Epoch 5: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1575s 9s/step - accuracy: 0.8852 - loss: 0.4308 - val_accuracy: 0.8893 - val_loss: 0.3841 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9085 - loss: 0.3686
# Epoch 6: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1675s 10s/step - accuracy: 0.9086 - loss: 0.3684 - val_accuracy: 0.9314 - val_loss: 0.2939 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9257 - loss: 0.2922
# Epoch 7: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1698s 10s/step - accuracy: 0.9257 - loss: 0.2922 - val_accuracy: 0.9400 - val_loss: 0.2613 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9400 - loss: 0.2592
# Epoch 8: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1710s 10s/step - accuracy: 0.9400 - loss: 0.2592 - val_accuracy: 0.9386 - val_loss: 0.2606 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9431 - loss: 0.2434
# Epoch 9: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1712s 10s/step - accuracy: 0.9431 - loss: 0.2433 - val_accuracy: 0.9536 - val_loss: 0.2074 - learning_rate: 0.0010
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9461 - loss: 0.2240
# Epoch 10: saving model to model.VGG19_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1706s 10s/step - accuracy: 0.9461 - loss: 0.2240 - val_accuracy: 0.9450 - val_loss: 0.2168 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 9.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9380 - loss: 0.1423
# Fold 3 - Test Loss:  0.20612367987632751
# Fold 3 - Test Accuracy:  0.9527616500854492
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step
# Classification Report for Fold 3
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.93      0.95       700
# Tuberculosis       0.93      0.98      0.95       700
#
#     accuracy                           0.95      1400
#    macro avg       0.95      0.95      0.95      1400
# weighted avg       0.95      0.95      0.95      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.4884 - loss: 96.2324
# Epoch 1: saving model to model.VGG19_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1716s 10s/step - accuracy: 0.4885 - loss: 95.8041 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5008 - loss: 0.6932
# Epoch 2: saving model to model.VGG19_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1728s 10s/step - accuracy: 0.5008 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5085 - loss: 0.6931
# Epoch 3: saving model to model.VGG19_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1658s 9s/step - accuracy: 0.5085 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5013 - loss: 0.6931
# Epoch 4: saving model to model.VGG19_fold_4.keras
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1709s 10s/step - accuracy: 0.5012 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5096 - loss: 0.6931
# Epoch 5: saving model to model.VGG19_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1665s 10s/step - accuracy: 0.5095 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-04
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.4956 - loss: 0.6932
# Epoch 6: saving model to model.VGG19_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1689s 10s/step - accuracy: 0.4957 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-04
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5066 - loss: 0.6931
# Epoch 7: saving model to model.VGG19_fold_4.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1679s 10s/step - accuracy: 0.5066 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-04
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5016 - loss: 0.6931
# Epoch 8: saving model to model.VGG19_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1736s 10s/step - accuracy: 0.5016 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 4.0000e-05
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.4925 - loss: 0.6932
# Epoch 9: saving model to model.VGG19_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1632s 9s/step - accuracy: 0.4926 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 4.0000e-05
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5041 - loss: 0.6931
# Epoch 10: saving model to model.VGG19_fold_4.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1614s 9s/step - accuracy: 0.5041 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 4.0000e-05
# Restoring model weights from the end of the best epoch: 10.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.8392 - loss: 0.6921
# Fold 4 - Test Loss:  0.693120539188385
# Fold 4 - Test Accuracy:  0.5087209343910217
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step
# Classification Report for Fold 4
#               precision    recall  f1-score   support
#
#       Normal       0.50      1.00      0.67       700
# Tuberculosis       0.00      0.00      0.00       700
#
#     accuracy                           0.50      1400
#    macro avg       0.25      0.50      0.33      1400
# weighted avg       0.25      0.50      0.33      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5573 - loss: 8.2027
# Epoch 1: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1636s 9s/step - accuracy: 0.5576 - loss: 8.1692 - val_accuracy: 0.6964 - val_loss: 0.5954 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.7948 - loss: 0.5475
# Epoch 2: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1729s 10s/step - accuracy: 0.7951 - loss: 0.5472 - val_accuracy: 0.8679 - val_loss: 0.4720 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.8887 - loss: 0.4297
# Epoch 3: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1715s 10s/step - accuracy: 0.8888 - loss: 0.4295 - val_accuracy: 0.9036 - val_loss: 0.4063 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9240 - loss: 0.3649
# Epoch 4: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1718s 10s/step - accuracy: 0.9240 - loss: 0.3649 - val_accuracy: 0.9121 - val_loss: 0.3684 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9267 - loss: 0.3370
# Epoch 5: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1717s 10s/step - accuracy: 0.9267 - loss: 0.3370 - val_accuracy: 0.9321 - val_loss: 0.3387 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9386 - loss: 0.2963
# Epoch 6: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1696s 10s/step - accuracy: 0.9387 - loss: 0.2962 - val_accuracy: 0.9429 - val_loss: 0.2888 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9418 - loss: 0.2628
# Epoch 7: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1674s 10s/step - accuracy: 0.9418 - loss: 0.2627 - val_accuracy: 0.9529 - val_loss: 0.2626 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9582 - loss: 0.2126
# Epoch 8: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1701s 10s/step - accuracy: 0.9582 - loss: 0.2126 - val_accuracy: 0.9636 - val_loss: 0.2034 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9704 - loss: 0.1769
# Epoch 9: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1740s 10s/step - accuracy: 0.9704 - loss: 0.1769 - val_accuracy: 0.9486 - val_loss: 0.2456 - learning_rate: 0.0010
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9724 - loss: 0.1553
# Epoch 10: saving model to model.VGG19_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1742s 10s/step - accuracy: 0.9724 - loss: 0.1553 - val_accuracy: 0.9471 - val_loss: 0.1956 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9169 - loss: 0.1756
# Fold 5 - Test Loss:  0.19518978893756866
# Fold 5 - Test Accuracy:  0.9462209343910217
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step
# Classification Report for Fold 5
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.91      0.95       700
# Tuberculosis       0.92      0.98      0.95       700
#
#     accuracy                           0.95      1400
#    macro avg       0.95      0.95      0.95      1400
# weighted avg       0.95      0.95      0.95      1400

# %%
print(f"Average accuracy over {k} folds: {np.mean(accuracies)}")
# Out:
# Average accuracy over 5 folds: 0.7780523300170898

# %%
fig, axs = plt.subplots(2, k, figsize=(15, 10))

for i in range(k):
    # Accuracy plot
    axs[0, i].plot(train_accuracies[i], label='Train Accuracy')
    axs[0, i].plot(val_accuracies[i], label='Validation Accuracy')
    axs[0, i].set_title(f'Fold {i+1} Accuracy')
    axs[0, i].set_xlabel('Epochs')
    axs[0, i].set_ylabel('Accuracy')
    axs[0, i].legend()

    # Loss plot
    axs[1, i].plot(train_losses[i], label='Train Loss')
    axs[1, i].plot(val_losses[i], label='Validation Loss')
    axs[1, i].set_title(f'Fold {i+1} Loss')
    axs[1, i].set_xlabel('Epochs')
    axs[1, i].set_ylabel('Loss')
    axs[1, i].legend()

plt.tight_layout()
plt.show()

# %%
# Plotting confusion matrices
for i, cm in enumerate(confusion_matrices):
    print(f"Confusion Matrix for Fold {i+1}")
    cm_df = pd.DataFrame(cm, index=classes, columns=classes)
    
    plt.figure(figsize=(8,6))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix for Fold {i+1}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()
# Out:
# Confusion Matrix for Fold 1
# Confusion Matrix for Fold 2
# Confusion Matrix for Fold 3
# Confusion Matrix for Fold 4
# Confusion Matrix for Fold 5

# %%
import tensorflow as tf
import pickle

# Save the model in HDF5 format
model.save(r"D:\CapstoneB\MKN maam\Model\VGG19kfoldpre.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("VGG19kfoldpre.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
