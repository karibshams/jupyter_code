# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

print('Modules loaded')
# Out:
# Modules loaded

# %%
data_dir =  r"D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB_Chest_Radiography_Database\image7500f"
filepaths = []
labels = []

for root, dirs, files in os.walk(data_dir):
    for file in files:
        file_path = os.path.join(root, file)
        filepaths.append(file_path)
        label = os.path.basename(root)
        labels.append(label)

df = pd.DataFrame({'filepaths': filepaths, 'labels': labels})
print(df)
# Out:
#                                               filepaths        labels
# 0     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 1     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 2     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 3     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# 4     D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...        Normal
# ...                                                 ...           ...
# 6995  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6996  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6997  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6998  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
# 6999  D:\CAPSTONE 400A\final_dataset\Tuberculosis\TB...  Tuberculosis
#
# [7000 rows x 2 columns]

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
epochs = 10
k = 5 
NUM_CLASSES = 2

# %%
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()
val_gen = ImageDataGenerator()

# %%
kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
fold_var = 1

train_scores = []
valid_scores = []
test_scores = []
y_preds = []

# %%
for train_index, val_index in kf.split(df['filepaths'], df['labels']):
    print(f'Fold {fold_var}')
    
    train_df = df.iloc[train_index]
    valid_df = df.iloc[val_index]
    test_df = df.iloc[val_index]  

    train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    valid_gen = val_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    test_gen = ts_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
    img_size = (224, 224)
    channels = 3
    img_shape = (img_size[0], img_size[1], channels)
    class_count = len(train_gen.class_indices)
    

    base_model = tf.keras.applications.DenseNet201(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')

    base_model.trainable = False  

    model = Sequential([
    base_model,
    BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001),
    Dense(512, kernel_initializer='he_normal', activation='relu'),
    Dropout(0.2),
    Dense(256, kernel_regularizer=regularizers.l2(0.009), activity_regularizer=regularizers.l1(0.019),
          bias_regularizer=regularizers.l1(0.019), activation='relu'),
    Dropout(0.20),
    Dense(128, kernel_initializer='he_uniform', activation='relu'),
    Dropout(0.1),
    Dense(class_count, activation='softmax')
])

    model.compile(optimizer=Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    #model.summary()

    
    history = model.fit(x=train_gen, epochs=epochs, verbose=1, validation_data=valid_gen, validation_steps=None, shuffle=False)
    
   
    ts_length = len(test_df)
    test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length % n == 0 and ts_length / n <= 80]))
    test_steps = ts_length // test_batch_size
    
    train_score = model.evaluate(train_gen, steps=test_steps, verbose=1)
    valid_score = model.evaluate(valid_gen, steps=test_steps, verbose=1)
    test_score = model.evaluate(test_gen, steps=test_steps, verbose=1)
    
    train_scores.append(train_score)
    valid_scores.append(valid_score)
    test_scores.append(test_score)
    
    preds = model.predict(test_gen)
    y_pred = np.argmax(preds, axis=1)
    y_preds.append(y_pred)
    
    fold_var += 1
# Out:
# Fold 1
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 1694s 10s/step - loss: 1.6605 - accuracy: 0.9295 - val_loss: 0.4874 - val_accuracy: 0.9593
# Epoch 2/10
# 175/175 [==============================] - 1557s 9s/step - loss: 0.3752 - accuracy: 0.9541 - val_loss: 0.2230 - val_accuracy: 0.9793
# Epoch 3/10
# 175/175 [==============================] - 911s 5s/step - loss: 0.2609 - accuracy: 0.9538 - val_loss: 0.1845 - val_accuracy: 0.9850
# Epoch 4/10
# 175/175 [==============================] - 941s 5s/step - loss: 0.2287 - accuracy: 0.9570 - val_loss: 0.1683 - val_accuracy: 0.9786
# Epoch 5/10
# 175/175 [==============================] - 937s 5s/step - loss: 0.1830 - accuracy: 0.9741 - val_loss: 0.1224 - val_accuracy: 0.9893
# Epoch 6/10
# 175/175 [==============================] - 938s 5s/step - loss: 0.1587 - accuracy: 0.9730 - val_loss: 0.1527 - val_accuracy: 0.9750
# Epoch 7/10
# 175/175 [==============================] - 953s 5s/step - loss: 0.1363 - accuracy: 0.9802 - val_loss: 0.1211 - val_accuracy: 0.9814
# Epoch 8/10
# 175/175 [==============================] - 940s 5s/step - loss: 0.1127 - accuracy: 0.9879 - val_loss: 0.1303 - val_accuracy: 0.9786
# Epoch 9/10
# 175/175 [==============================] - 939s 5s/step - loss: 0.1155 - accuracy: 0.9834 - val_loss: 0.0925 - val_accuracy: 0.9879
# Epoch 10/10
# 175/175 [==============================] - 936s 5s/step - loss: 0.0981 - accuracy: 0.9891 - val_loss: 0.0832 - val_accuracy: 0.9914
# 20/20 [==============================] - 85s 4s/step - loss: 0.0649 - accuracy: 0.9984
# 20/20 [==============================] - 85s 4s/step - loss: 0.0821 - accuracy: 0.9953
# 20/20 [==============================] - 86s 4s/step - loss: 0.0849 - accuracy: 0.9922
# 44/44 [==============================] - 190s 4s/step
# Fold 2
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 951s 5s/step - loss: 1.6696 - accuracy: 0.9327 - val_loss: 0.4976 - val_accuracy: 0.9686
# Epoch 2/10
# 175/175 [==============================] - 946s 5s/step - loss: 0.3882 - accuracy: 0.9480 - val_loss: 0.2615 - val_accuracy: 0.9771
# Epoch 3/10
# 175/175 [==============================] - 939s 5s/step - loss: 0.2701 - accuracy: 0.9563 - val_loss: 0.2543 - val_accuracy: 0.9536
# Epoch 4/10
# 175/175 [==============================] - 1482s 8s/step - loss: 0.2196 - accuracy: 0.9661 - val_loss: 0.1628 - val_accuracy: 0.9836
# Epoch 5/10
# 175/175 [==============================] - 1586s 9s/step - loss: 0.1737 - accuracy: 0.9771 - val_loss: 0.1337 - val_accuracy: 0.9879
# Epoch 6/10
# 175/175 [==============================] - 1586s 9s/step - loss: 0.1266 - accuracy: 0.9862 - val_loss: 0.1344 - val_accuracy: 0.9850
# Epoch 7/10
# 175/175 [==============================] - 1581s 9s/step - loss: 0.1311 - accuracy: 0.9804 - val_loss: 0.1254 - val_accuracy: 0.9843
# Epoch 8/10
# 175/175 [==============================] - 1441s 8s/step - loss: 0.1227 - accuracy: 0.9811 - val_loss: 0.1081 - val_accuracy: 0.9736
# Epoch 9/10
# 175/175 [==============================] - 904s 5s/step - loss: 0.1033 - accuracy: 0.9870 - val_loss: 0.1120 - val_accuracy: 0.9886
# Epoch 10/10
# 175/175 [==============================] - 926s 5s/step - loss: 0.1087 - accuracy: 0.9875 - val_loss: 0.0962 - val_accuracy: 0.9900
# 20/20 [==============================] - 85s 4s/step - loss: 0.0722 - accuracy: 0.9969
# 20/20 [==============================] - 85s 4s/step - loss: 0.0935 - accuracy: 0.9891
# 20/20 [==============================] - 85s 4s/step - loss: 0.1089 - accuracy: 0.9875
# 44/44 [==============================] - 187s 4s/step
# Fold 3
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 969s 5s/step - loss: 1.5975 - accuracy: 0.9354 - val_loss: 0.4599 - val_accuracy: 0.9593
# Epoch 2/10
# 175/175 [==============================] - 957s 5s/step - loss: 0.3734 - accuracy: 0.9443 - val_loss: 0.2344 - val_accuracy: 0.9693
# Epoch 3/10
# 175/175 [==============================] - 959s 5s/step - loss: 0.2397 - accuracy: 0.9634 - val_loss: 0.1749 - val_accuracy: 0.9800
# Epoch 4/10
# 175/175 [==============================] - 952s 5s/step - loss: 0.2095 - accuracy: 0.9614 - val_loss: 0.1505 - val_accuracy: 0.9864
# Epoch 5/10
# 175/175 [==============================] - 955s 5s/step - loss: 0.1861 - accuracy: 0.9671 - val_loss: 0.1339 - val_accuracy: 0.9879
# Epoch 6/10
# 175/175 [==============================] - 1028s 6s/step - loss: 0.1495 - accuracy: 0.9736 - val_loss: 0.1163 - val_accuracy: 0.9779
# Epoch 7/10
# 175/175 [==============================] - 1363s 8s/step - loss: 0.1364 - accuracy: 0.9782 - val_loss: 0.1147 - val_accuracy: 0.9857
# Epoch 8/10
# 175/175 [==============================] - 936s 5s/step - loss: 0.1324 - accuracy: 0.9777 - val_loss: 0.1297 - val_accuracy: 0.9857
# Epoch 9/10
# 175/175 [==============================] - 1101s 6s/step - loss: 0.1381 - accuracy: 0.9804 - val_loss: 0.1098 - val_accuracy: 0.9893
# Epoch 10/10
# 175/175 [==============================] - 960s 5s/step - loss: 0.1000 - accuracy: 0.9900 - val_loss: 0.0948 - val_accuracy: 0.9921
# 20/20 [==============================] - 88s 4s/step - loss: 0.0646 - accuracy: 1.0000
# 20/20 [==============================] - 87s 4s/step - loss: 0.0952 - accuracy: 0.9906
# 20/20 [==============================] - 87s 4s/step - loss: 0.1093 - accuracy: 0.9937
# 44/44 [==============================] - 196s 4s/step
# Fold 4
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 1004s 6s/step - loss: 1.5928 - accuracy: 0.9312 - val_loss: 0.4541 - val_accuracy: 0.9650
# Epoch 2/10
# 175/175 [==============================] - 972s 6s/step - loss: 0.3566 - accuracy: 0.9521 - val_loss: 0.2219 - val_accuracy: 0.9771
# Epoch 3/10
# 175/175 [==============================] - 970s 6s/step - loss: 0.2455 - accuracy: 0.9614 - val_loss: 0.1806 - val_accuracy: 0.9786
# Epoch 4/10
# 175/175 [==============================] - 972s 6s/step - loss: 0.2129 - accuracy: 0.9586 - val_loss: 0.1777 - val_accuracy: 0.9779
# Epoch 5/10
# 175/175 [==============================] - 1554s 9s/step - loss: 0.1749 - accuracy: 0.9743 - val_loss: 0.1280 - val_accuracy: 0.9857
# Epoch 6/10
# 175/175 [==============================] - 1688s 10s/step - loss: 0.1465 - accuracy: 0.9752 - val_loss: 0.1327 - val_accuracy: 0.9807
# Epoch 7/10
# 175/175 [==============================] - 1193s 7s/step - loss: 0.1458 - accuracy: 0.9787 - val_loss: 0.1098 - val_accuracy: 0.9871
# Epoch 8/10
# 175/175 [==============================] - 1002s 6s/step - loss: 0.1201 - accuracy: 0.9832 - val_loss: 0.1083 - val_accuracy: 0.9886
# Epoch 9/10
# 175/175 [==============================] - 994s 6s/step - loss: 0.1454 - accuracy: 0.9755 - val_loss: 0.1128 - val_accuracy: 0.9907
# Epoch 10/10
# 175/175 [==============================] - 976s 6s/step - loss: 0.1049 - accuracy: 0.9870 - val_loss: 0.1059 - val_accuracy: 0.9871
# 20/20 [==============================] - 92s 5s/step - loss: 0.0744 - accuracy: 0.9953
# 20/20 [==============================] - 100s 5s/step - loss: 0.1114 - accuracy: 0.9828
# 20/20 [==============================] - 104s 5s/step - loss: 0.1222 - accuracy: 0.9828
# 44/44 [==============================] - 208s 5s/step
# Fold 5
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 [==============================] - 995s 6s/step - loss: 1.5744 - accuracy: 0.9332 - val_loss: 0.4694 - val_accuracy: 0.9600
# Epoch 2/10
# 175/175 [==============================] - 990s 6s/step - loss: 0.3666 - accuracy: 0.9477 - val_loss: 0.2567 - val_accuracy: 0.9564
# Epoch 3/10
# 175/175 [==============================] - 1021s 6s/step - loss: 0.2447 - accuracy: 0.9677 - val_loss: 0.1827 - val_accuracy: 0.9771
# Epoch 4/10
# 175/175 [==============================] - 978s 6s/step - loss: 0.2190 - accuracy: 0.9652 - val_loss: 0.3916 - val_accuracy: 0.9550
# Epoch 5/10
# 175/175 [==============================] - 978s 6s/step - loss: 0.1906 - accuracy: 0.9748 - val_loss: 0.1402 - val_accuracy: 0.9850
# Epoch 6/10
# 175/175 [==============================] - 979s 6s/step - loss: 0.1395 - accuracy: 0.9846 - val_loss: 0.1920 - val_accuracy: 0.9507
# Epoch 7/10
# 175/175 [==============================] - 979s 6s/step - loss: 0.1377 - accuracy: 0.9825 - val_loss: 0.1276 - val_accuracy: 0.9843
# Epoch 8/10
# 175/175 [==============================] - 983s 6s/step - loss: 0.1143 - accuracy: 0.9873 - val_loss: 0.1347 - val_accuracy: 0.9671
# Epoch 9/10
# 175/175 [==============================] - 983s 6s/step - loss: 0.0989 - accuracy: 0.9877 - val_loss: 0.1145 - val_accuracy: 0.9786
# Epoch 10/10
# 175/175 [==============================] - 1016s 6s/step - loss: 0.0942 - accuracy: 0.9898 - val_loss: 0.1001 - val_accuracy: 0.9786
# 20/20 [==============================] - 92s 5s/step - loss: 0.0605 - accuracy: 0.9984
# 20/20 [==============================] - 91s 5s/step - loss: 0.1006 - accuracy: 0.9781
# 20/20 [==============================] - 93s 5s/step - loss: 0.0703 - accuracy: 0.9937
# 44/44 [==============================] - 203s 5s/step

# %%
train_loss = np.mean([score[0] for score in train_scores])
train_acc = np.mean([score[1] for score in train_scores])
valid_loss = np.mean([score[0] for score in valid_scores])
valid_acc = np.mean([score[1] for score in valid_scores])
test_loss = np.mean([score[0] for score in test_scores])
test_acc = np.mean([score[1] for score in test_scores])

print("Train Loss: ", train_loss)
print("Train Accuracy: ", train_acc)
print('-' * 20)
print("Validation Loss: ", valid_loss)
print("Validation Accuracy: ", valid_acc)
print('-' * 20)
print("Test Loss: ", test_loss)
print("Test Accuracy: ", test_acc)
# Out:
# Train Loss:  0.06729863733053207
# Train Accuracy:  0.9978125095367432
# --------------------
# Validation Loss:  0.09655951410531997
# Validation Accuracy:  0.9871875047683716
# --------------------
# Test Loss:  0.099126635491848
# Test Accuracy:  0.9899999976158143

# %%
y_true = test_gen.classes
classes = list(train_gen.class_indices.keys())
print(classification_report(y_true, y_preds[-1], target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.99      0.98       700
# Tuberculosis       0.99      0.96      0.98       700
#
#     accuracy                           0.98      1400
#    macro avg       0.98      0.98      0.98      1400
# weighted avg       0.98      0.98      0.98      1400

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


cm = confusion_matrix(y_true, y_preds[-1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)

# Plot confusion matrix
plt.figure(figsize=(10, 10))
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import tensorflow as tf
import pickle

# Save the model in HDF5 format
model.save(r"D:\CAPSTONE 400A\model\DenseNet201kfoldcus.h5")

# %%
model.save("DenseNet201kfoldcus.h5")
