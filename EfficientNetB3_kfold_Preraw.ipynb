# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adamax
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

print('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r"D:\CapstoneB\MKN maam\image7500f"
filepaths = []
labels = []

for root, dirs, files in os.walk(data_dir):
    for file in files:
        file_path = os.path.join(root, file)
        filepaths.append(file_path)
        label = os.path.basename(root)
        labels.append(label)

df = pd.DataFrame({'filepaths': filepaths, 'labels': labels})
labels = df['labels']
print(df)
# Out:
#                                               filepaths        labels
# 0     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 1     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 2     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 3     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 4     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# ...                                                 ...           ...
# 6995  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6996  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6997  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6998  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6999  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
#
# [7000 rows x 2 columns]

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
epochs = 10
k = 5  
NUM_CLASSES = 2

# %%
def get_callbacks(model_name):
    callbacks = []
    checkpoint = ModelCheckpoint(filepath=f'model.{model_name}.keras', verbose=1, monitor='val_accuracy', mode='max')
    callbacks.append(checkpoint)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
    callbacks.append(reduce_lr)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
    callbacks.append(early_stopping)
    return callbacks

def build_model():
    base_model = tf.keras.applications.EfficientNetB3(input_shape=img_shape, include_top=False, weights='imagenet')
    base_model.trainable = True
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer=Adamax(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=123)
fold_no = 1
accuracies = []

# %%
# Create lists to store history data for each fold
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []

# Create a list to store confusion matrices
confusion_matrices = []

for train_index, test_index in skf.split(df['filepaths'], df['labels']):
    train_df = df.iloc[train_index]
    test_df = df.iloc[test_index]

    tr_gen = ImageDataGenerator()
    ts_gen = ImageDataGenerator()

    train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels',
                                           target_size=img_size, class_mode='categorical',
                                           color_mode='rgb', shuffle=True, batch_size=batch_size)

    test_gen = ts_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels',
                                          target_size=img_size, class_mode='categorical',
                                          color_mode='rgb', shuffle=False, batch_size=batch_size)

    g_dict = train_gen.class_indices
    classes = list(g_dict.keys())
    class_count = len(classes)

    model = build_model()
    callbacks = get_callbacks(f'EfficientNetB3_fold_{fold_no}')

    history = model.fit(train_gen,
                        epochs=epochs,
                        validation_data=test_gen,
                        callbacks=callbacks)

    # Store history data
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])

    ts_length = len(test_df)
    test_batch_size = min(32, ts_length)
    test_steps = ts_length // test_batch_size

    test_score = model.evaluate(test_gen, steps=test_steps, verbose=1)
    print(f"Fold {fold_no} - Test Loss: ", test_score[0])
    print(f"Fold {fold_no} - Test Accuracy: ", test_score[1])

    preds = model.predict(test_gen)
    y_pred = np.argmax(preds, axis=1)
    print(f"Classification Report for Fold {fold_no}")
    print(classification_report(test_gen.classes, y_pred, target_names=classes))

    # Store confusion matrix
    cm = confusion_matrix(test_gen.classes, y_pred)
    confusion_matrices.append(cm)

    accuracies.append(test_score[1])
    fold_no += 1
# Out:
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9711 - loss: 0.0743
# Epoch 1: saving model to model.EfficientNetB3_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1007s 5s/step - accuracy: 0.9713 - loss: 0.0740 - val_accuracy: 0.9993 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9995 - loss: 0.0023
# Epoch 2: saving model to model.EfficientNetB3_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 936s 5s/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9993 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9994 - loss: 0.0013
# Epoch 3: saving model to model.EfficientNetB3_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 921s 5s/step - accuracy: 0.9994 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 7.5015e-04 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 7.4274e-04
# Epoch 4: saving model to model.EfficientNetB3_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 890s 5s/step - accuracy: 1.0000 - loss: 7.4127e-04 - val_accuracy: 1.0000 - val_loss: 1.3107e-04 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9989 - loss: 0.0028
# Epoch 5: saving model to model.EfficientNetB3_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 891s 5s/step - accuracy: 0.9989 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 6.1219e-04 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 4.6050e-04
# Epoch 6: saving model to model.EfficientNetB3_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 890s 5s/step - accuracy: 1.0000 - loss: 4.6112e-04 - val_accuracy: 1.0000 - val_loss: 1.0283e-04 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 3.0944e-04
# Epoch 7: saving model to model.EfficientNetB3_fold_1.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 890s 5s/step - accuracy: 1.0000 - loss: 3.0869e-04 - val_accuracy: 1.0000 - val_loss: 8.5637e-05 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 1.5436e-04
# Epoch 8: saving model to model.EfficientNetB3_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 889s 5s/step - accuracy: 1.0000 - loss: 1.5410e-04 - val_accuracy: 1.0000 - val_loss: 1.0153e-04 - learning_rate: 2.0000e-04
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 6.5478e-05
# Epoch 9: saving model to model.EfficientNetB3_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 889s 5s/step - accuracy: 1.0000 - loss: 6.5474e-05 - val_accuracy: 1.0000 - val_loss: 1.3174e-04 - learning_rate: 2.0000e-04
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 1.4897e-04
# Epoch 10: saving model to model.EfficientNetB3_fold_1.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 890s 5s/step - accuracy: 1.0000 - loss: 1.4873e-04 - val_accuracy: 1.0000 - val_loss: 8.6661e-05 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 7.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 778ms/step - accuracy: 1.0000 - loss: 3.9822e-05
# Fold 1 - Test Loss:  8.702488412382081e-05
# Fold 1 - Test Accuracy:  1.0
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 850ms/step
# Classification Report for Fold 1
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9746 - loss: 0.0591
# Epoch 1: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 943s 5s/step - accuracy: 0.9747 - loss: 0.0589 - val_accuracy: 0.9993 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9997 - loss: 0.0014
# Epoch 2: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 892s 5s/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9993 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9987 - loss: 0.0029
# Epoch 3: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 891s 5s/step - accuracy: 0.9987 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 5.7612e-04
# Epoch 4: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 893s 5s/step - accuracy: 1.0000 - loss: 5.7579e-04 - val_accuracy: 1.0000 - val_loss: 8.4312e-04 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 1.6408e-04
# Epoch 5: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 894s 5s/step - accuracy: 1.0000 - loss: 1.6401e-04 - val_accuracy: 1.0000 - val_loss: 5.0444e-05 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 7.0456e-05
# Epoch 6: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 892s 5s/step - accuracy: 1.0000 - loss: 7.0508e-05 - val_accuracy: 1.0000 - val_loss: 6.0118e-05 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 5.6104e-05
# Epoch 7: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 901s 5s/step - accuracy: 1.0000 - loss: 5.6218e-05 - val_accuracy: 1.0000 - val_loss: 1.0529e-04 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 2.9610e-05
# Epoch 8: saving model to model.EfficientNetB3_fold_2.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 931s 5s/step - accuracy: 1.0000 - loss: 2.9606e-05 - val_accuracy: 1.0000 - val_loss: 1.0501e-04 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9995 - loss: 8.3154e-04
# Epoch 9: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 929s 5s/step - accuracy: 0.9995 - loss: 8.2887e-04 - val_accuracy: 1.0000 - val_loss: 1.7374e-04 - learning_rate: 2.0000e-04
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9998 - loss: 6.4288e-04
# Epoch 10: saving model to model.EfficientNetB3_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 923s 5s/step - accuracy: 0.9998 - loss: 6.4742e-04 - val_accuracy: 1.0000 - val_loss: 4.7877e-04 - learning_rate: 2.0000e-04
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 812ms/step - accuracy: 1.0000 - loss: 3.6451e-05
# Fold 2 - Test Loss:  5.0829010433517396e-05
# Fold 2 - Test Accuracy:  1.0
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 41s 884ms/step
# Classification Report for Fold 2
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9700 - loss: 0.0642
# Epoch 1: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 942s 5s/step - accuracy: 0.9702 - loss: 0.0640 - val_accuracy: 0.9957 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9999 - loss: 0.0015
# Epoch 2: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 894s 5s/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9993 - val_loss: 9.3957e-04 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9985 - loss: 0.0043
# Epoch 3: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 894s 5s/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9998 - loss: 0.0012
# Epoch 4: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 897s 5s/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 0.9993 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9996 - loss: 0.0019
# Epoch 5: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 894s 5s/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 1.2961e-04 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9997 - loss: 5.8678e-04
# Epoch 6: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 894s 5s/step - accuracy: 0.9997 - loss: 5.8637e-04 - val_accuracy: 1.0000 - val_loss: 3.7525e-04 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 2.6915e-04
# Epoch 7: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 896s 5s/step - accuracy: 1.0000 - loss: 2.6836e-04 - val_accuracy: 1.0000 - val_loss: 1.1269e-04 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 5.6457e-05
# Epoch 8: saving model to model.EfficientNetB3_fold_3.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 895s 5s/step - accuracy: 1.0000 - loss: 5.6432e-05 - val_accuracy: 1.0000 - val_loss: 6.5750e-05 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 4.5738e-04
# Epoch 9: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 894s 5s/step - accuracy: 1.0000 - loss: 4.5660e-04 - val_accuracy: 1.0000 - val_loss: 8.1590e-05 - learning_rate: 2.0000e-04
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 4.0288e-05
# Epoch 10: saving model to model.EfficientNetB3_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 907s 5s/step - accuracy: 1.0000 - loss: 4.0524e-05 - val_accuracy: 1.0000 - val_loss: 7.0708e-05 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 8.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 786ms/step - accuracy: 1.0000 - loss: 4.5466e-05
# Fold 3 - Test Loss:  6.687309360131621e-05
# Fold 3 - Test Accuracy:  1.0
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 41s 885ms/step
# Classification Report for Fold 3
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9706 - loss: 0.0703
# Epoch 1: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 945s 5s/step - accuracy: 0.9707 - loss: 0.0700 - val_accuracy: 0.9971 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9994 - loss: 0.0019
# Epoch 2: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 903s 5s/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9979 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9997 - loss: 0.0022
# Epoch 3: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 928s 5s/step - accuracy: 0.9997 - loss: 0.0022 - val_accuracy: 0.9993 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9998 - loss: 8.2979e-04
# Epoch 4: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 937s 5s/step - accuracy: 0.9998 - loss: 8.3160e-04 - val_accuracy: 0.9993 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9991 - loss: 0.0029
# Epoch 5: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 938s 5s/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 8.9461e-04 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 2.0999e-04
# Epoch 6: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 905s 5s/step - accuracy: 1.0000 - loss: 2.0987e-04 - val_accuracy: 1.0000 - val_loss: 5.5359e-04 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 9.7206e-05
# Epoch 7: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 904s 5s/step - accuracy: 1.0000 - loss: 9.7258e-05 - val_accuracy: 1.0000 - val_loss: 5.3985e-04 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9998 - loss: 6.4509e-04
# Epoch 8: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 905s 5s/step - accuracy: 0.9998 - loss: 6.4862e-04 - val_accuracy: 0.9993 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 1.9198e-04
# Epoch 9: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 904s 5s/step - accuracy: 1.0000 - loss: 1.9163e-04 - val_accuracy: 1.0000 - val_loss: 2.8392e-04 - learning_rate: 0.0010
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 4.0259e-05
# Epoch 10: saving model to model.EfficientNetB3_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 939s 5s/step - accuracy: 1.0000 - loss: 4.0292e-05 - val_accuracy: 1.0000 - val_loss: 1.2572e-04 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 37s 862ms/step - accuracy: 1.0000 - loss: 1.0661e-04
# Fold 4 - Test Loss:  0.00012310406600590795
# Fold 4 - Test Accuracy:  1.0
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 44s 933ms/step
# Classification Report for Fold 4
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9668 - loss: 0.0624
# Epoch 1: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1004s 5s/step - accuracy: 0.9669 - loss: 0.0622 - val_accuracy: 0.9993 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9974 - loss: 0.0065
# Epoch 2: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 957s 5s/step - accuracy: 0.9974 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9999 - loss: 8.5123e-04
# Epoch 3: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 956s 5s/step - accuracy: 0.9999 - loss: 8.5362e-04 - val_accuracy: 0.9964 - val_loss: 0.0130 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 4.7653e-04
# Epoch 4: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 920s 5s/step - accuracy: 1.0000 - loss: 4.7637e-04 - val_accuracy: 1.0000 - val_loss: 7.3392e-04 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9996 - loss: 6.8174e-04
# Epoch 5: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 905s 5s/step - accuracy: 0.9996 - loss: 6.8254e-04 - val_accuracy: 1.0000 - val_loss: 7.8539e-05 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9995 - loss: 0.0016
# Epoch 6: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 904s 5s/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9993 - val_loss: 9.2542e-04 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9999 - loss: 4.7273e-04
# Epoch 7: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 905s 5s/step - accuracy: 0.9999 - loss: 4.7559e-04 - val_accuracy: 0.9993 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 7.3870e-04
# Epoch 8: saving model to model.EfficientNetB3_fold_5.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 905s 5s/step - accuracy: 1.0000 - loss: 7.3727e-04 - val_accuracy: 1.0000 - val_loss: 7.0833e-05 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9995 - loss: 9.2950e-04
# Epoch 9: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 905s 5s/step - accuracy: 0.9995 - loss: 9.3388e-04 - val_accuracy: 1.0000 - val_loss: 4.5765e-05 - learning_rate: 2.0000e-04
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 2.3013e-04
# Epoch 10: saving model to model.EfficientNetB3_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 906s 5s/step - accuracy: 1.0000 - loss: 2.2955e-04 - val_accuracy: 1.0000 - val_loss: 3.2419e-05 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 10.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 805ms/step - accuracy: 1.0000 - loss: 1.7779e-05
# Fold 5 - Test Loss:  3.261274105170742e-05
# Fold 5 - Test Accuracy:  1.0
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 855ms/step
# Classification Report for Fold 5
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400

# %%
print(f"Average accuracy over {k} folds: {np.mean(accuracies)}")
# Out:
# Average accuracy over 5 folds: 1.0

# %%
fig, axs = plt.subplots(2, k, figsize=(15, 10))

for i in range(k):
    # Accuracy plot
    axs[0, i].plot(train_accuracies[i], label='Train Accuracy')
    axs[0, i].plot(val_accuracies[i], label='Validation Accuracy')
    axs[0, i].set_title(f'Fold {i+1} Accuracy')
    axs[0, i].set_xlabel('Epochs')
    axs[0, i].set_ylabel('Accuracy')
    axs[0, i].legend()

    # Loss plot
    axs[1, i].plot(train_losses[i], label='Train Loss')
    axs[1, i].plot(val_losses[i], label='Validation Loss')
    axs[1, i].set_title(f'Fold {i+1} Loss')
    axs[1, i].set_xlabel('Epochs')
    axs[1, i].set_ylabel('Loss')
    axs[1, i].legend()

plt.tight_layout()
plt.show()

# %%
# Plotting confusion matrices
for i, cm in enumerate(confusion_matrices):
    print(f"Confusion Matrix for Fold {i+1}")
    cm_df = pd.DataFrame(cm, index=classes, columns=classes)
    
    plt.figure(figsize=(8,6))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix for Fold {i+1}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()
# Out:
# Confusion Matrix for Fold 1
# Confusion Matrix for Fold 2
# Confusion Matrix for Fold 3
# Confusion Matrix for Fold 4
# Confusion Matrix for Fold 5

# %%
import tensorflow as tf
import pickle

# Save the model in HDF5 format
model.save(r"D:\CapstoneB\MKN maam\Model\EfficientNetB3kfoldpre.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("EfficientNetB3kfoldpre.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
