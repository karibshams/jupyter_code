# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adamax
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

print('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r"D:\CapstoneB\MKN maam\image7500f"
filepaths = []
labels = []

for root, dirs, files in os.walk(data_dir):
    for file in files:
        file_path = os.path.join(root, file)
        filepaths.append(file_path)
        label = os.path.basename(root)
        labels.append(label)

df = pd.DataFrame({'filepaths': filepaths, 'labels': labels})
labels = df['labels']
print(df)
# Out:
#                                               filepaths        labels
# 0     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 1     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 2     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 3     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# 4     D:\CapstoneB\MKN maam\image7500f\image7500f\No...        Normal
# ...                                                 ...           ...
# 6995  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6996  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6997  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6998  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
# 6999  D:\CapstoneB\MKN maam\image7500f\image7500f\Tu...  Tuberculosis
#
# [7000 rows x 2 columns]

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
epochs = 10
k = 5  
NUM_CLASSES = 2

# %%
def get_callbacks(model_name):
    callbacks = []
    checkpoint = ModelCheckpoint(filepath=f'model.{model_name}.keras', verbose=1, monitor='val_accuracy', mode='max')
    callbacks.append(checkpoint)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
    callbacks.append(reduce_lr)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
    callbacks.append(early_stopping)
    return callbacks

def build_model():
    base_model = tf.keras.applications.ResNet50(input_shape=img_shape, include_top=False, weights='imagenet')
    base_model.trainable = True
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer=Adamax(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=123)
fold_no = 1
accuracies = []

# %%
# Create lists to store history data for each fold
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []

# Create a list to store confusion matrices
confusion_matrices = []

for train_index, test_index in skf.split(df['filepaths'], df['labels']):
    train_df = df.iloc[train_index]
    test_df = df.iloc[test_index]

    tr_gen = ImageDataGenerator()
    ts_gen = ImageDataGenerator()

    train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels',
                                           target_size=img_size, class_mode='categorical',
                                           color_mode='rgb', shuffle=True, batch_size=batch_size)

    test_gen = ts_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels',
                                          target_size=img_size, class_mode='categorical',
                                          color_mode='rgb', shuffle=False, batch_size=batch_size)

    g_dict = train_gen.class_indices
    classes = list(g_dict.keys())
    class_count = len(classes)

    model = build_model()
    callbacks = get_callbacks(f'ResNet50_fold_{fold_no}')

    history = model.fit(train_gen,
                        epochs=epochs,
                        validation_data=test_gen,
                        callbacks=callbacks)

    # Store history data
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])

    ts_length = len(test_df)
    test_batch_size = min(32, ts_length)
    test_steps = ts_length // test_batch_size

    test_score = model.evaluate(test_gen, steps=test_steps, verbose=1)
    print(f"Fold {fold_no} - Test Loss: ", test_score[0])
    print(f"Fold {fold_no} - Test Accuracy: ", test_score[1])

    preds = model.predict(test_gen)
    y_pred = np.argmax(preds, axis=1)
    print(f"Classification Report for Fold {fold_no}")
    print(classification_report(test_gen.classes, y_pred, target_names=classes))

    # Store confusion matrix
    cm = confusion_matrix(test_gen.classes, y_pred)
    confusion_matrices.append(cm)

    accuracies.append(test_score[1])
    fold_no += 1
# Out:
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9567 - loss: 0.1137
# Epoch 1: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 804s 4s/step - accuracy: 0.9568 - loss: 0.1133 - val_accuracy: 0.5000 - val_loss: 20.0066 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9951 - loss: 0.0105
# Epoch 2: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 766s 4s/step - accuracy: 0.9951 - loss: 0.0105 - val_accuracy: 0.9907 - val_loss: 0.0166 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9985 - loss: 0.0034
# Epoch 3: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 772s 4s/step - accuracy: 0.9985 - loss: 0.0034 - val_accuracy: 0.9986 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 3.0758e-04
# Epoch 4: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 774s 4s/step - accuracy: 1.0000 - loss: 3.0755e-04 - val_accuracy: 1.0000 - val_loss: 3.2273e-04 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.9043e-04
# Epoch 5: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 775s 4s/step - accuracy: 1.0000 - loss: 1.9046e-04 - val_accuracy: 0.9993 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.7476e-04
# Epoch 6: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 776s 4s/step - accuracy: 1.0000 - loss: 1.7463e-04 - val_accuracy: 1.0000 - val_loss: 2.1280e-04 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.3701e-04
# Epoch 7: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 757s 4s/step - accuracy: 1.0000 - loss: 1.3683e-04 - val_accuracy: 1.0000 - val_loss: 3.1824e-04 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 5.1904e-05
# Epoch 8: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 753s 4s/step - accuracy: 1.0000 - loss: 5.1865e-05 - val_accuracy: 1.0000 - val_loss: 1.8961e-04 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.1621e-05
# Epoch 9: saving model to model.ResNet50_fold_1.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 786s 4s/step - accuracy: 1.0000 - loss: 1.1635e-05 - val_accuracy: 1.0000 - val_loss: 1.9757e-04 - learning_rate: 0.0010
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.7005e-05
# Epoch 10: saving model to model.ResNet50_fold_1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 762s 4s/step - accuracy: 1.0000 - loss: 1.7090e-05 - val_accuracy: 1.0000 - val_loss: 5.0695e-04 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 8.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 808ms/step - accuracy: 1.0000 - loss: 2.4613e-04
# Fold 1 - Test Loss:  0.00019288617477286607
# Fold 1 - Test Accuracy:  1.0
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 842ms/step
# Classification Report for Fold 1
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9584 - loss: 0.1244
# Epoch 1: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 779s 4s/step - accuracy: 0.9585 - loss: 0.1240 - val_accuracy: 0.5364 - val_loss: 7.3417 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9973 - loss: 0.0058
# Epoch 2: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 779s 4s/step - accuracy: 0.9973 - loss: 0.0058 - val_accuracy: 0.9986 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9992 - loss: 0.0020
# Epoch 3: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 771s 4s/step - accuracy: 0.9992 - loss: 0.0020 - val_accuracy: 0.9464 - val_loss: 0.2309 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9999 - loss: 0.0015
# Epoch 4: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 772s 4s/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.6671 - val_loss: 2.2765 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9987 - loss: 0.0044
# Epoch 5: saving model to model.ResNet50_fold_2.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 763s 4s/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.9643 - val_loss: 0.1682 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9990 - loss: 0.0032
# Epoch 6: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 777s 4s/step - accuracy: 0.9990 - loss: 0.0032 - val_accuracy: 0.9993 - val_loss: 0.0022 - learning_rate: 2.0000e-04
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 7: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 783s 4s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9993 - val_loss: 0.0017 - learning_rate: 2.0000e-04
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 2.8454e-04
# Epoch 8: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 792s 5s/step - accuracy: 1.0000 - loss: 2.8469e-04 - val_accuracy: 0.9986 - val_loss: 0.0046 - learning_rate: 2.0000e-04
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 2.4743e-04
# Epoch 9: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 785s 4s/step - accuracy: 1.0000 - loss: 2.4786e-04 - val_accuracy: 0.9993 - val_loss: 0.0032 - learning_rate: 2.0000e-04
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 5.5931e-04
# Epoch 10: saving model to model.ResNet50_fold_2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 750s 4s/step - accuracy: 1.0000 - loss: 5.6059e-04 - val_accuracy: 0.9986 - val_loss: 0.0013 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 10.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 37s 850ms/step - accuracy: 0.9990 - loss: 8.9071e-04
# Fold 2 - Test Loss:  0.0013018855825066566
# Fold 2 - Test Accuracy:  0.9985465407371521
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 42s 916ms/step
# Classification Report for Fold 2
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9572 - loss: 0.1118
# Epoch 1: saving model to model.ResNet50_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 813s 5s/step - accuracy: 0.9574 - loss: 0.1114 - val_accuracy: 0.9986 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9989 - loss: 0.0030
# Epoch 2: saving model to model.ResNet50_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 794s 5s/step - accuracy: 0.9989 - loss: 0.0030 - val_accuracy: 0.9786 - val_loss: 0.0514 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9992 - loss: 0.0013
# Epoch 3: saving model to model.ResNet50_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 788s 5s/step - accuracy: 0.9992 - loss: 0.0013 - val_accuracy: 0.9971 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9992 - loss: 0.0025
# Epoch 4: saving model to model.ResNet50_fold_3.keras
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 786s 4s/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.9979 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9999 - loss: 0.0017
# Epoch 5: saving model to model.ResNet50_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 769s 4s/step - accuracy: 0.9999 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 8.0609e-04 - learning_rate: 2.0000e-04
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9998 - loss: 6.1339e-04
# Epoch 6: saving model to model.ResNet50_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 764s 4s/step - accuracy: 0.9998 - loss: 6.1284e-04 - val_accuracy: 1.0000 - val_loss: 1.8236e-04 - learning_rate: 2.0000e-04
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.0432e-04
# Epoch 7: saving model to model.ResNet50_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 762s 4s/step - accuracy: 1.0000 - loss: 1.0444e-04 - val_accuracy: 1.0000 - val_loss: 1.4731e-04 - learning_rate: 2.0000e-04
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.1263e-04
# Epoch 8: saving model to model.ResNet50_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 782s 4s/step - accuracy: 1.0000 - loss: 1.1267e-04 - val_accuracy: 1.0000 - val_loss: 1.5534e-04 - learning_rate: 2.0000e-04
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.3854e-04
# Epoch 9: saving model to model.ResNet50_fold_3.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 789s 5s/step - accuracy: 1.0000 - loss: 1.3839e-04 - val_accuracy: 1.0000 - val_loss: 1.4255e-04 - learning_rate: 2.0000e-04
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 5.2925e-05
# Epoch 10: saving model to model.ResNet50_fold_3.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 772s 4s/step - accuracy: 1.0000 - loss: 5.2968e-05 - val_accuracy: 1.0000 - val_loss: 1.0810e-04 - learning_rate: 4.0000e-05
# Restoring model weights from the end of the best epoch: 10.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 36s 844ms/step - accuracy: 1.0000 - loss: 9.0828e-05
# Fold 3 - Test Loss:  0.00010998181096510962
# Fold 3 - Test Accuracy:  1.0
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 848ms/step
# Classification Report for Fold 3
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9629 - loss: 0.1151
# Epoch 1: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 798s 4s/step - accuracy: 0.9630 - loss: 0.1148 - val_accuracy: 0.9936 - val_loss: 0.0300 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9978 - loss: 0.0087
# Epoch 2: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 778s 4s/step - accuracy: 0.9978 - loss: 0.0086 - val_accuracy: 0.9064 - val_loss: 0.3530 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9991 - loss: 0.0034
# Epoch 3: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 783s 4s/step - accuracy: 0.9991 - loss: 0.0034 - val_accuracy: 0.7657 - val_loss: 2.1003 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9986 - loss: 0.0037
# Epoch 4: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 780s 4s/step - accuracy: 0.9986 - loss: 0.0037 - val_accuracy: 0.9993 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9993 - loss: 0.0051
# Epoch 5: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 799s 5s/step - accuracy: 0.9993 - loss: 0.0051 - val_accuracy: 0.9629 - val_loss: 0.1038 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9988 - loss: 0.0036
# Epoch 6: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 792s 5s/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9986 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9999 - loss: 3.8671e-04
# Epoch 7: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 776s 4s/step - accuracy: 0.9999 - loss: 3.8768e-04 - val_accuracy: 0.9993 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9993 - loss: 0.0018
# Epoch 8: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 808s 5s/step - accuracy: 0.9993 - loss: 0.0018 - val_accuracy: 0.8457 - val_loss: 0.5585 - learning_rate: 0.0010
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 4.7601e-04
# Epoch 9: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 791s 5s/step - accuracy: 1.0000 - loss: 4.7538e-04 - val_accuracy: 1.0000 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 8.8480e-05
# Epoch 10: saving model to model.ResNet50_fold_4.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 805s 5s/step - accuracy: 1.0000 - loss: 8.8375e-05 - val_accuracy: 1.0000 - val_loss: 0.0012 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 9.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 39s 893ms/step - accuracy: 1.0000 - loss: 0.0011
# Fold 4 - Test Loss:  0.0010256385430693626
# Fold 4 - Test Accuracy:  1.0
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 42s 917ms/step
# Classification Report for Fold 4
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400
#
# Found 5600 validated image filenames belonging to 2 classes.
# Found 1400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9645 - loss: 0.1179
# Epoch 1: saving model to model.ResNet50_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 823s 5s/step - accuracy: 0.9646 - loss: 0.1175 - val_accuracy: 0.8714 - val_loss: 0.8836 - learning_rate: 0.0010
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9984 - loss: 0.0059
# Epoch 2: saving model to model.ResNet50_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 845s 5s/step - accuracy: 0.9984 - loss: 0.0059 - val_accuracy: 0.9936 - val_loss: 0.0228 - learning_rate: 0.0010
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9983 - loss: 0.0049
# Epoch 3: saving model to model.ResNet50_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 791s 5s/step - accuracy: 0.9983 - loss: 0.0049 - val_accuracy: 0.5100 - val_loss: 10.2757 - learning_rate: 0.0010
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9999 - loss: 0.0016
# Epoch 4: saving model to model.ResNet50_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 781s 4s/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 0.9986 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9998 - loss: 6.8156e-04
# Epoch 5: saving model to model.ResNet50_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 791s 5s/step - accuracy: 0.9997 - loss: 6.8494e-04 - val_accuracy: 0.9907 - val_loss: 0.0309 - learning_rate: 0.0010
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9996 - loss: 9.3922e-04
# Epoch 6: saving model to model.ResNet50_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 781s 4s/step - accuracy: 0.9996 - loss: 9.3700e-04 - val_accuracy: 0.9936 - val_loss: 0.0188 - learning_rate: 0.0010
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9992 - loss: 0.0027
# Epoch 7: saving model to model.ResNet50_fold_5.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 776s 4s/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.9579 - val_loss: 0.1266 - learning_rate: 0.0010
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 7.5866e-04
# Epoch 8: saving model to model.ResNet50_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 782s 4s/step - accuracy: 1.0000 - loss: 7.5930e-04 - val_accuracy: 0.9643 - val_loss: 0.0788 - learning_rate: 2.0000e-04
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 1.7837e-04
# Epoch 9: saving model to model.ResNet50_fold_5.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 801s 5s/step - accuracy: 1.0000 - loss: 1.7848e-04 - val_accuracy: 0.9986 - val_loss: 0.0030 - learning_rate: 2.0000e-04
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9997 - loss: 9.3137e-04
# Epoch 10: saving model to model.ResNet50_fold_5.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 838s 5s/step - accuracy: 0.9997 - loss: 9.2966e-04 - val_accuracy: 0.9986 - val_loss: 0.0036 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 9.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 37s 847ms/step - accuracy: 0.9964 - loss: 0.0057
# Fold 5 - Test Loss:  0.003067108104005456
# Fold 5 - Test Accuracy:  0.9985465407371521
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step
# Classification Report for Fold 5
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       700
# Tuberculosis       1.00      1.00      1.00       700
#
#     accuracy                           1.00      1400
#    macro avg       1.00      1.00      1.00      1400
# weighted avg       1.00      1.00      1.00      1400

# %%
print(f"Average accuracy over {k} folds: {np.mean(accuracies)}")
# Out:
# Average accuracy over 5 folds: 0.9994186162948608

# %%
fig, axs = plt.subplots(2, k, figsize=(15, 10))

for i in range(k):
    # Accuracy plot
    axs[0, i].plot(train_accuracies[i], label='Train Accuracy')
    axs[0, i].plot(val_accuracies[i], label='Validation Accuracy')
    axs[0, i].set_title(f'Fold {i+1} Accuracy')
    axs[0, i].set_xlabel('Epochs')
    axs[0, i].set_ylabel('Accuracy')
    axs[0, i].legend()

    # Loss plot
    axs[1, i].plot(train_losses[i], label='Train Loss')
    axs[1, i].plot(val_losses[i], label='Validation Loss')
    axs[1, i].set_title(f'Fold {i+1} Loss')
    axs[1, i].set_xlabel('Epochs')
    axs[1, i].set_ylabel('Loss')
    axs[1, i].legend()

plt.tight_layout()
plt.show()

# %%
# Plotting confusion matrices
for i, cm in enumerate(confusion_matrices):
    print(f"Confusion Matrix for Fold {i+1}")
    cm_df = pd.DataFrame(cm, index=classes, columns=classes)
    
    plt.figure(figsize=(8,6))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix for Fold {i+1}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()
# Out:
# Confusion Matrix for Fold 1
# Confusion Matrix for Fold 2
# Confusion Matrix for Fold 3
# Confusion Matrix for Fold 4
# Confusion Matrix for Fold 5

# %%
import tensorflow as tf
import pickle

# Save the model in HDF5 format
model.save(r"D:\CapstoneB\MKN maam\Model\resnet50kfoldpre.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("resnet50kfoldpre.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
